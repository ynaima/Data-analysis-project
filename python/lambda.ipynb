# %% [markdown]
# Lambda functions

# %%
#lambda functions can be assigned to variables
multipleTwo = lambda x: x*2

#invoking or calling the function uses the variable name with parenthesis
multipleTwo(2)
# Out:
# 4

# %%
#we can also call the function within the lambda expression but not using variable name
(lambda x: x*2)(2)
# Out:
# 4

# %%
#we can use multiple arguments
(lambda x, y: x*2 + y)(2, 3)
# Out:
# 7

# %%
#using lamda function instead within list comprehension
salary_list = [100000, 200000, 150000, 120000, 80000, 750000]
bonus_rate=.1
# Calculate total_salary of base_salary * (1 + bonus_rate)
# def calculate_salary(base_salary, bonus_rate=.1):
#   return base_salary * (1 + bonus_rate)

# [round(calculate_salary(salary), 2) for salary in salary_list]


#solution: we want to have a list with total salaries but now using lambda

# or just
[round(salary * 1.1) for salary in salary_list]
# Out:
# [110000, 220000, 165000, 132000, 88000, 825000]

# %%
help(filter)
# Out:
# Help on class filter in module builtins:
#
# class filter(object)
#  |  filter(function, iterable, /)
#  |
#  |  Return an iterator yielding those items of iterable for which function(item)
#  |  is true. If function is None, return the items that are true.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
jobs_data = [
    {'job_title': 'Data Scientist',  'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst',  'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

#filter function takes two arguments: a function and an iterable
#using filter function to filter out a list of jobs where job is remote and has the skill required for python
list(filter(lambda job: job['remote'] and 'Python' in job['job_skills'], jobs_data))
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Keras'],
#   'remote': True}]

# %% [markdown]
# #Problems

# %% [markdown]
# 🟩 Calculate Average Salary (1.17.1)

# %%
# Code Needed
salaries = [95000, 120000, 105000, 90000, 130000]
#print(sum(salaries)/5)
average_calculator = lambda x: round(sum(x)/len(salaries), 2)
average_calculator(salaries)
# Out:
# 108000.0
# 108000.0

# %% [markdown]
#  🟨 Filter Job Titles (1.17.2)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst']
titles = lambda titles: titles[:]
titles(job_titles)
# Out:
# ['Data Scientist',
#  'Data Engineer',
#  'Machine Learning Engineer',
#  'Data Analyst']

# %% [markdown]
# 🟥 Filter Remote Python Jobs (1.17.3)

# %%
# Code Needed
job_postings = [
    {'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
    {'title': 'Data Analyst', 'skills': ['Excel', 'SQL'], 'remote': False},
    {'title': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow'], 'remote': True},
    {'title': 'Software Developer', 'skills': ['Java', 'C++'], 'remote': True}
]

#using filter function
list(filter(lambda job: job['remote']  and 'Python' in job['skills'], job_postings))
# Out:
# [{'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
#  {'title': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow'],
#   'remote': True}]
