# %% [markdown]
# # Basics
# 1. Variables
#     - CamelCase in python
#     - start with characters and under_score
#     - No special characters
#     - No built -in function names
#     - No python keywords
#     - Aliasing in Variables
#     - Reasigning variables
# 2. Data Types: int, Boolean, strings
#     - using Type() function
#     - Converting between data types
#     - str(5) | int(5) || float(4)
#     - f-strings   age =50  f"Age {variable}: older than 5"
#     - Name errors
#     - Indentation errors
#     - type errors
#     - magic methods/dunder methods eg: __add__ for str, int
# 4. Built- in Functions
#     - built-in-functions for int, str
#     - len(), join(), print() etc
#     - string concatenation
# 5. Classes
#    -  __init__ class
#    -  The use of self
#    -  Methods
#    -  Attributes
#    -  Invoking/calling methods
#    -  Creating classes
# 7. Conditionals
#    - If else statements
#    - elif statements
#    - use of comparison and logical operators with if-else and elif statements
# 9. Operators: Comparison & Logical Operators & Arithmetic
#     - AND  OR  NOT
#     - ==  != >= <= > <
#     - ** POWER * MULTIPLY + - // INTEGER DIVISION % MODULUS OPERATOR / FLOOR DIVISION
# 11. Dictionaries, lists, Tuples, Sets
# 13. Assignment Operator
#     using shorthand += or -=
# 15. Loops
#     -while loops
#     -for loops
# 17. List comprehensions
# 18. Functions
